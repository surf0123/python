# %% [markdown]
# <a href="https://colab.research.google.com/github/surf0123/python/blob/main/bbb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 비디오 플레이하기
#  v=  b5akCiGbOl0 에서 파일명 붙이면 된다.

# %%
from IPython.display import YouTubeVideo, display 
video = YouTubeVideo("b5akCiGbOl0", width=500) 
display(video)

# %%
import cv2
cv2.__version__
# Out:
# '4.1.2'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 사진 올리기

# %%
import matplotlib.pyplot as plt
from PIL import Image
# PIL은 oepn()으로 image file을 읽어서 ImageFile객체로 생성. 
pil_image = Image.open("/content/drive/MyDrive/pomi.jpg")
print('image type:', type(pil_image))

plt.figure(figsize=(5, 5))
plt.imshow(pil_image)
# Out:
# image type: <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
import matplotlib.pyplot as plt
from PIL import Image
# PIL은 oepn()으로 image file을 읽어서 ImageFile객체로 생성. 
img = Image.open("/content/sample_data/lenna.jpg")
print('image type:', type(img))

plt.figure(figsize=(5, 5))
plt.imshow(img)
# Out:
# image type: <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %% [markdown]
# ## 강아지 종류 분류하기

# %%
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
# PIL은 oepn()으로 image file을 읽어서 ImageFile객체로 생성. 
img = Image.open("/content/sample_data/pomi.jpg")
img = img.resize((224,224))
img_array = image.img_to_array(img)
img_batch = np.expand_dims(img_array, axis=0)
img_preprocessed = preprocess_input(img_batch)
model = tf.keras.applications.resnet50.ResNet50()
prediction = model.predict(img_preprocessed)
print(decode_predictions(prediction, top=3)[0])
plt.figure(figsize=(5, 5))
plt.imshow(pil_image)
# Out:
# [('n02085936', 'Maltese_dog', 0.95836663), ('n02098413', 'Lhasa', 0.019639479), ('n02086240', 'Shih-Tzu', 0.0075547365)]
